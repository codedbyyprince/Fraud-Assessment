# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/media/prince/5A4E832F4E83034D/Fraud-Detector-ML/Data/Fraud_Data.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 590540 entries, 0 to 590539
# Data columns (total 41 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   transaction_id           590540 non-null  float64
#  1   is_fraud                 590540 non-null  float64
#  2   transaction_time         590540 non-null  float64
#  3   transaction_amount       590540 non-null  float64
#  4   card_network             590540 non-null  object
#  5   card_type                590540 non-null  object
#  6   purchaser_email_domain   590540 non-null  object
#  7   device_type              590540 non-null  object
#  8   is_identity_seen_before  590540 non-null  object
#  9   user_os                  590540 non-null  object
#  10  user_browser             590540 non-null  object
#  11  environment              590540 non-null  object
#  12  environment_freq         590540 non-null  float64
# ...

# %%
keep_features = [
    # Original categoricals
    'card_network',
    'card_type',
    'purchaser_email_domain',
    'user_browser',
    'time_hour',
    'amt_bins',
    'day_of_week',
    'time_diff_bins',
    # Combined / engineered categoricals
    'known_env_risk',
    'device_typ_os',
    'pemail_user_os',
    'card_net_user_os',
    'card_type_user_os',
    'user_os_browser',
    'id_seen_user_browser',
    'browser_card_type',
    'id_seen_amt_bin',
    'time_diff_bins_hour',
    # Numeric features
    'amt_log',
    'time_diff_log'
]

# Also ensure you keep the target if it's still in the dataframe
# target = 'is_fraud'   # uncomment if you need to keep target

# Drop any column not in the keep list (plus optionally the target)
columns_to_drop = [col for col in df.columns if col not in keep_features and col != 'is_fraud']
df = df.drop(columns=columns_to_drop)

for i in df.columns.tolist():
    print(i)
# Out:
# is_fraud
# card_network
# card_type
# purchaser_email_domain
# user_browser
# time_hour
# amt_log
# amt_bins
# day_of_week
# time_diff_log
# device_typ_os
# known_env_risk
# time_diff_bins
# card_net_user_os
# card_type_user_os
# pemail_user_os
# id_seen_user_browser
# user_os_browser
# browser_card_type
# time_diff_bins_hour
# id_seen_amt_bin

# %%
df.to_csv('/media/prince/5A4E832F4E83034D/Fraud-Detector-ML/Data/model_v3_feas.csv', index=False)

# %%
df2 = pd.read_csv('/media/prince/5A4E832F4E83034D/Fraud-Detector-ML/Data/model_v3_feas.csv')

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 590540 entries, 0 to 590539
# Data columns (total 21 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   is_fraud                590540 non-null  float64
#  1   card_network            590540 non-null  object
#  2   card_type               590540 non-null  object
#  3   purchaser_email_domain  590540 non-null  object
#  4   user_browser            590540 non-null  object
#  5   time_hour               590540 non-null  float64
#  6   amt_log                 590540 non-null  float64
#  7   amt_bins                590540 non-null  float64
#  8   day_of_week             590540 non-null  float64
#  9   time_diff_log           590540 non-null  float64
#  10  device_typ_os           590540 non-null  object
#  11  known_env_risk          590540 non-null  object
#  12  time_diff_bins          590540 non-null  int64
#  13  card_net_user_os        590540 non-null  object
# ...
