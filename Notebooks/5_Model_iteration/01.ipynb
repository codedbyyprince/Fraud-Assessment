# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns 
from scipy.stats import chi2_contingency

# %%
df = pd.read_csv('/media/prince/5A4E832F4E83034D/Fraud-Detector-ML/Data/Fraud_Data.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 590540 entries, 0 to 590539
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   transaction_id           590540 non-null  int64
#  1   is_fraud                 590540 non-null  int64
#  2   transaction_time         590540 non-null  int64
#  3   transaction_amount       590540 non-null  float64
#  4   card_network             588963 non-null  object
#  5   card_type                588969 non-null  object
#  6   purchaser_email_domain   496084 non-null  object
#  7   device_type              140810 non-null  object
#  8   is_identity_seen_before  129340 non-null  object
#  9   user_os                  144233 non-null  object
#  10  user_browser             144233 non-null  object
#  11  environment              144233 non-null  object
#  12  environment_freq         144233 non-null  float64
#  13  environment_risk         144233 non-null  float64
#  14  device_os_invalid        144233 non-null  float64
# dtypes: float64(4), int64(3), object(8)
# memory usage: 67.6+ MB

# %%
df = df.drop(columns=['device_os_invalid'])

# %%
df['transaction_time']
# Out:
# 0            86400
# 1            86401
# 2            86469
# 3            86499
# 4            86506
#             ...
# 590535    15811047
# 590536    15811049
# 590537    15811079
# 590538    15811088
# 590539    15811131
# Name: transaction_time, Length: 590540, dtype: int64

# %%
df['transaction_time'].max()
# Out:
# 15811131

# %%
df['time_hour'] = (df['transaction_time'] // 3600) % 24
df['time_day']  = df['transaction_time'] / 86400
df['time_diff'] = df['transaction_time'].diff()
df['time_diff_min'] = df['time_diff'] / 60

# %%
df[['time_day', 'time_hour', 'time_diff_min']]
# Out:
#           time_day  time_hour  time_diff_min
# 0         1.000000          0            NaN
# 1         1.000012          0       0.016667
# 2         1.000799          0       1.133333
# 3         1.001146          0       0.500000
# 4         1.001227          0       0.116667
# ...            ...        ...            ...
# 590535  182.998229         23       0.283333
# 590536  182.998252         23       0.033333
# 590537  182.998600         23       0.500000
# 590538  182.998704         23       0.150000
# 590539  182.999201         23       0.716667
#
# [590540 rows x 3 columns]

# %%
df['time_diff_min'].min()
# Out:
# 0.0

# %%
plt.figure(figsize=(6, 5))

sns.violinplot(
    data=df,
    x='is_fraud',
    y='time_day'
)

plt.xticks([0, 1], ['Not Fraud', 'Fraud'])
plt.xlabel('Fraud or Not')
plt.ylabel('Transaction days')
plt.title('Violin Plot: Effect of Days on Fraud')
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 590540 entries, 0 to 590539
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   transaction_id           590540 non-null  int64
#  1   is_fraud                 590540 non-null  int64
#  2   transaction_time         590540 non-null  int64
#  3   transaction_amount       590540 non-null  float64
#  4   card_network             588963 non-null  object
#  5   card_type                588969 non-null  object
#  6   purchaser_email_domain   496084 non-null  object
#  7   device_type              140810 non-null  object
#  8   is_identity_seen_before  129340 non-null  object
#  9   user_os                  144233 non-null  object
#  10  user_browser             144233 non-null  object
#  11  environment              144233 non-null  object
#  12  environment_freq         144233 non-null  float64
#  13  environment_risk         144233 non-null  float64
#  14  time_hour                590540 non-null  int64
#  15  time_day                 590540 non-null  float64
#  16  time_diff                590539 non-null  float64
#  17  time_diff_min            590539 non-null  float64
# dtypes: float64(6), int64(4), object(8)
# memory usage: 81.1+ MB

# %%
df['amt_log'] = np.log1p(df['transaction_amount'])

# %%
df['amt_bins'] = pd.qcut(df['amt_log'], q =10 ,labels=False )

# %%
fraud_rate = df.groupby('amt_bins')['is_fraud'].mean() * 100

plt.figure(figsize=(10,5))
plt.bar(fraud_rate.index, fraud_rate.values, color='red', alpha=0.7)
plt.xlabel('Amount Bin (Decile)')
plt.ylabel('Fraud Rate %')
plt.title('Fraud Rate by Transaction Amount Bin')
plt.xticks(range(10))
plt.show()

# %%
df['time_diff'].describe()
# Out:
# count    590539.000000
# mean         26.627760
# std          59.299088
# min           0.000000
# 25%           5.000000
# 50%          13.000000
# 75%          29.000000
# max        4138.000000
# Name: time_diff, dtype: float64

# %%
start = df.index[df['time_hour'] == 0][0]
end   = df.index[df['time_hour'] == 23][0]

df_first_day = df.loc[start:end]

# %%
fraud_rate = df_first_day.groupby('time_hour')['is_fraud'].mean() * 100

plt.figure(figsize=(10,5))
plt.bar(fraud_rate.index, fraud_rate.values, color='red', alpha=0.7)
plt.xlabel('Time in hours')
plt.ylabel('Fraud Rate %')
plt.title('Fraud Rate per hour')
plt.xticks(range(24))
plt.show()

# %%
ct = pd.crosstab(df_first_day['time_hour'], df['is_fraud'])
ct * 100
# Out:
# is_fraud       0     1
# time_hour
# 0          22700   100
# 1          19500   600
# 2          18000     0
# 3          13100   300
# 4           8900   300
# 5           6300   100
# 6           9000   100
# 7           6600     0
# 8           3400   400
# 9           4000   100
# 10          4500   200
# 11          7700   500
# 12         14400   400
# 13         22100   100
# 14         25100   700
# 15         32000   800
# 16         36900   700
# 17         37700   500
# 18         37300   500
# 19         36900   800
# 20         33000  1300
# 21         35200   900
# 22         32400   700
# 23           100     0

# %%
chi2, p, dof, exp = chi2_contingency(ct)
print(p)
# Out:
# 0.009648148408401221

# %%
n = ct.values.sum()
cramers_v = np.sqrt(chi2 / (n * (min(ct.shape) - 1)))
print(cramers_v)
# Out:
# 0.09359062560148748

# %%
df = df.copy()

# detect where cycle resets (hour drops, e.g., 23 → 0 or 24 → 1)
df['new_day'] = df['time_hour'].diff() < 0

# cumulative sum → gives day number
df['day_id'] = df['new_day'].cumsum()
pivot = df.pivot_table(
    index='time_hour',
    columns='day_id',
    values='is_fraud',  # replace this
    aggfunc='mean'
)
pivot.var(axis=1)
# Out:
# time_hour
# 0     0.000464
# 1     0.000512
# 2     0.001051
# 3     0.001184
# 4     0.002845
# 5     0.005262
# 6     0.006571
# 7     0.017540
# 8     0.011245
# 9     0.016003
# 10    0.012636
# 11    0.005956
# 12    0.001453
# 13    0.000412
# 14    0.000462
# 15    0.000430
# 16    0.000525
# 17    0.000452
# 18    0.000397
# 19    0.000486
# 20    0.000488
# 21    0.000415
# 22    0.000354
# 23    0.000598
# dtype: float64

# %%
import matplotlib.pyplot as plt

pivot.plot(legend=False, alpha=0.2)
plt.show()

# %%
df['day_of_week'] = df['time_day'].astype(int) % 7

# %%
# fraud_by_day = df.groupby('day_id')['is_fraud'].mean()
fraud_by_day = df.groupby('day_of_week')['is_fraud'].mean()

plt.plot(fraud_by_day.index, fraud_by_day.values)
plt.xlabel('Day')
plt.ylabel('Fraud Rate')
plt.title('Fraud Rate over Days')
plt.show()

# %%
df['time_diff_log'] = np.log1p(df['time_diff'])

# %%
for i in df.columns:
    print(i)
# Out:
# transaction_id
# is_fraud
# transaction_time
# transaction_amount
# card_network
# card_type
# purchaser_email_domain
# device_type
# is_identity_seen_before
# user_os
# user_browser
# environment
# environment_freq
# environment_risk
# time_hour
# time_day
# time_diff
# time_diff_min
# amt_log
# amt_bins
# new_day
# day_id
# day_of_week
# time_diff_log

# %%
# df = df.drop(columns=['transaction_id', 'transaction_time','environment', 'environment_freq', 'time_diff', 'time_diff_min', 'amt_log', 'new_day', 'day_id'])

# df.to_csv('/media/prince/5A4E832F4E83034D/Fraud-Detector-ML/Notebooks/5_model_iteration/model_v2_feas.csv', index=False)

# %%
df2 = pd.read_csv('/media/prince/5A4E832F4E83034D/Fraud-Detector-ML/Notebooks/5_model_iteration/model_v2_feas.csv')

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 588912 entries, 0 to 588911
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   is_fraud                 588912 non-null  int64
#  1   transaction_amount       588912 non-null  float64
#  2   card_network             588912 non-null  object
#  3   card_type                588912 non-null  object
#  4   purchaser_email_domain   494686 non-null  object
#  5   device_type              140606 non-null  object
#  6   is_identity_seen_before  129173 non-null  object
#  7   user_os                  144028 non-null  object
#  8   user_browser             144028 non-null  object
#  9   environment_risk         144028 non-null  float64
#  10  card_info                588912 non-null  object
#  11  time_hour                588912 non-null  int64
#  12  time_day                 588912 non-null  float64
#  13  amt_bins                 588912 non-null  int64
#  14  day_of_week              588912 non-null  int64
#  15  time_diff_log            588911 non-null  float64
# dtypes: float64(4), int64(4), object(8)
# memory usage: 71.9+ MB

# %%
df['card_network']
# Out:
# 0           discover
# 1         mastercard
# 2               visa
# 3         mastercard
# 4         mastercard
#              ...
# 590535          visa
# 590536    mastercard
# 590537    mastercard
# 590538    mastercard
# 590539    mastercard
# Name: card_network, Length: 590540, dtype: object

# %%
df.to_csv('/media/prince/5A4E832F4E83034D/Fraud-Detector-ML/Data/Fraud_Data.csv', index=False)
